# %% [markdown]
# # 02 — Embeddings
#
# Explore sentence-transformer embeddings.

# %%
import sys
sys.path.insert(0, '..')

from src.embeddings.embeddings import get_embeddings

emb = get_embeddings()
vec = emb.embed_query('What is Newton\'s first law?')
print(f'Dimension: {len(vec)}')
