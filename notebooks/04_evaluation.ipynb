# %% [markdown]
# # 04 — Evaluation
#
# Run retrieval metrics on the default eval set.

# %%
import sys
sys.path.insert(0, '..')

from src.evaluation.evaluate import run_evaluation
from src.retrieval.retriever import get_retriever

retriever = get_retriever()
run_evaluation(retriever)
